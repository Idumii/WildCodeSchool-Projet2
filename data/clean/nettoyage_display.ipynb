# %%
# Imports
import pandas as pd
import numpy as np

# %%
# On récupere le df final utilisé pour le machine learning
df = pd.read_csv('../../ressources/df_final.csv', sep=';')
df
# Out:
#           tconst       primaryTitle  \
# 0      tt0006864        Intolerance
# 1      tt0009968    Broken Blossoms
# 2      tt0010307          J'accuse!
# 3      tt0010418    Male and Female
# 4      tt0011439  The Mark of Zorro
# ...          ...                ...
# 17266  tt9902160            Herself
# 17267  tt9904802        Enemy Lines
# 17268  tt9907782         The Cursed
# 17269  tt9908390            Le lion
# 17270  tt9916362              Coven
#
#                                                   title  \
# 0      Intolerance: Love's Struggle Throughout the Ages
# 1                                       Broken Blossoms
# 2                                              J'accuse
# 3                                       Male and Female
# 4                                     The Mark of Zorro
# ...                                                 ...
# 17266                                           Herself
# 17267                                       Enemy Lines
# ...

# %%
# Pour l'affichage on garde les colonnes suivantes:
# tconst / id / frenchTitle / primaryTitle / averageRating / runtimeMinutes / genres / startYear / overview / acteurs / directors 
df = df[['tconst', 'id', 'frenchTitle', 'primaryTitle', 'averageRating', 'runtimeMinutes', 'genres', 'startYear', 'overview', 'actor1', 'actor2', 'actor3', 'directors']]

df
# Out:
#           tconst      id               frenchTitle       primaryTitle  \
# 0      tt0006864    3059               Intolérance        Intolerance
# 1      tt0009968     899              Le lys brisé    Broken Blossoms
# 2      tt0010307   70804                  J'accuse          J'accuse!
# 3      tt0010418   53761      L'admirable Crichton    Male and Female
# 4      tt0011439   42657         Le signe de Zorro  The Mark of Zorro
# ...          ...     ...                       ...                ...
# 17266  tt9902160  653708                   Herself            Herself
# 17267  tt9904802  679796               Enemy Lines        Enemy Lines
# 17268  tt9907782  630392          Eight for Silver         The Cursed
# 17269  tt9908390  589970                   Le lion            Le lion
# 17270  tt9916362  655187  Les sorcières d'Akelarre              Coven
#
#        averageRating  runtimeMinutes  \
# 0                7.7             163
# 1                7.2              90
# ...

# %%
# On concatene  les colonnes acteurs pour en faire une seule
df['acteurs'] = df['actor1'] + ', ' + df['actor2'] + ', ' + df['actor3']
# On supprime les colonnes inutiles
df = df.drop(columns=['actor1', 'actor2', 'actor3'])
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_29724\52039359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['acteurs'] = df['actor1'] + ', ' + df['actor2'] + ', ' + df['actor3']
#           tconst      id               frenchTitle       primaryTitle  \
# 0      tt0006864    3059               Intolérance        Intolerance
# 1      tt0009968     899              Le lys brisé    Broken Blossoms
# 2      tt0010307   70804                  J'accuse          J'accuse!
# 3      tt0010418   53761      L'admirable Crichton    Male and Female
# 4      tt0011439   42657         Le signe de Zorro  The Mark of Zorro
# ...          ...     ...                       ...                ...
# ...

# %%
# On va devoir récuperer les colonnes qui nous manquent pour l'affichage:
# affiche / bande-annonce / classification

# %%
# Récuperer des id:
# https://api.themoviedb.org/3/movie/{movie_id}/external_ids

# %%
# Récuperer les videos:
# https://api.themoviedb.org/3/movie/{movie_id}/videos?language=fr-FR"
