# %% [markdown]
# Exploration Fichiers CSV

# %%
import pandas as pd
import gdown

# %%
# Liens vers les fichiers de données IMDb
# Ces fichiers sont disponibles en téléchargement sur le site IMDb
link_title_basics = "https://datasets.imdbws.com/title.basics.tsv.gz"
link_title_akas = "https://datasets.imdbws.com/title.akas.tsv.gz"
link_title_crew = "https://datasets.imdbws.com/title.crew.tsv.gz"
#link_title_episode = "https://datasets.imdbws.com/title.episode.tsv.gz" -> non utilisé car pas de séries
link_title_principals = "https://datasets.imdbws.com/title.principals.tsv.gz"
link_title_ratings = "https://datasets.imdbws.com/title.ratings.tsv.gz"
link_name_basics = "https://datasets.imdbws.com/name.basics.tsv.gz"
link_tmdb = "https://drive.google.com/file/d/1VB5_gl1fnyBDzcIOXZ5vUSbCY68VZN1v/view"

# %%
# Fichier TMDB
file_id = "1VB5_gl1fnyBDzcIOXZ5vUSbCY68VZN1v"
output = "../ressources/tmdb_movies.csv"
#gdown.download(id=file_id,
#               output=output,
#               quiet=False,      # affiche la barre de progression
#               fuzzy=True)

# %%
df_name_basics = pd.read_csv(link_name_basics, sep="\t", low_memory=False)
df_title_principals = pd.read_csv(link_title_principals, sep="\t", low_memory=False)
df_title_crew = pd.read_csv(link_title_crew, sep="\t", low_memory=False)
df_title_akas = pd.read_csv(link_title_akas, sep="\t", low_memory=False)
df_title_ratings = pd.read_csv(link_title_ratings, sep="\t", low_memory=False)
df_tmdb = pd.read_csv(output, low_memory=False)
df_title_basics = pd.read_csv(link_title_basics, sep="\t", low_memory=False)

# %%
# Début du traitement des fichiers IMDb
# Début nettoyage title.basics.tsv.gz
# Tous les genres de films existants dans le fichier title.basics.tsv.gz
genre_exploded = (
    df_title_basics["genres"]
    .str.split(",")
    .explode()
    .str.strip()
)
genre_exploded.unique()
# Out:
# array(['Documentary', 'Short', 'Animation', 'Comedy', 'Romance', 'Sport',
#        'News', 'Drama', 'Fantasy', 'Horror', 'Biography', 'Music', 'War',
#        'Crime', 'Western', 'Family', 'Adventure', 'Action', 'History',
#        'Mystery', '\\N', 'Sci-Fi', 'Musical', 'Thriller', 'Film-Noir',
#        'Talk-Show', 'Game-Show', 'Reality-TV', 'Adult', nan], dtype=object)

# %%
# Copy
df_title_basics_copy = df_title_basics.copy()
df_title_basics_copy.tail(3)
# Out:
#              tconst  titleType               primaryTitle  \
# 11686807  tt9916852  tvEpisode              Episode #3.20
# 11686808  tt9916856      short                   The Wind
# 11686809  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 11686807              Episode #3.20       0      2010      \N             \N
# 11686808                   The Wind       0      2015      \N             27
# 11686809  Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres
# 11686807                       Drama
# 11686808                       Short
# 11686809  Adventure,Animation,Comedy

# %%
# Remplacer NaN et \\N par "Unknown"
df_title_basics_copy["genres"] = df_title_basics_copy["genres"].str.replace("\\N", "Unknown", regex=False)
df_title_basics_copy["genres"] = df_title_basics_copy["genres"].fillna("Unknown")

# Genre non gardé : Documentary / Short / News / Talk-show / Game-Show / Reality-TV / Adult 
# On les enlève de la liste des genres
list_genre_to_drop = ["Documentary", "Short", "News", "Talk-show", "Game-Show", "Reality-TV", "Adult"]
regex_pattern = '|'.join(map(lambda x: f'({x})', list_genre_to_drop))
df_title_basics_copy = df_title_basics_copy[~df_title_basics_copy['genres'].str.contains(regex_pattern, regex=True)]

display(df_title_basics_copy.head(3))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17224\2010509105.py:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_title_basics_copy = df_title_basics_copy[~df_title_basics_copy['genres'].str.contains(regex_pattern, regex=True)]
#         tconst titleType                                     primaryTitle  \
# 2    tt0000003     short                                     Poor Pierrot
# 8    tt0000009     movie                                       Miss Jerry
# 208  tt0000211     short  The Astronomer's Dream; or, The Man in the Moon
#
#           originalTitle isAdult startYear endYear runtimeMinutes  \
# 2        Pauvre Pierrot       0      1892      \N              5
# 8            Miss Jerry       0      1894      \N             45
# 208  La lune à un mètre       0      1898      \N              3
#
#                        genres
# 2    Animation,Comedy,Romance
# 8                     Romance
# 208     Comedy,Fantasy,Horror

# %%
# Verifier les différents types de films
df_title_basics_copy['titleType'].unique()

# On récupere uniquement les films
df_title_basics_copy = df_title_basics_copy[df_title_basics_copy['titleType'] == 'movie']

# On enlève les films pour adultes

df_title_basics_copy = df_title_basics_copy[df_title_basics_copy['isAdult'] == '0']

# On enlève les films sans titre
df_title_basics_copy['primaryTitle'] = df_title_basics_copy['primaryTitle'].fillna('None.')

display(df_title_basics_copy[df_title_basics_copy['primaryTitle'].isna() == False].head(3))
# Out:
#         tconst titleType                 primaryTitle  \
# 8    tt0000009     movie                   Miss Jerry
# 498  tt0000502     movie                     Bohemios
# 570  tt0000574     movie  The Story of the Kelly Gang
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 8                     Miss Jerry       0      1894      \N             45
# 498                     Bohemios       0      1905      \N            100
# 570  The Story of the Kelly Gang       0      1906      \N             70
#
#                          genres
# 8                       Romance
# 498                     Unknown
# 570  Action,Adventure,Biography

# %%
print(df_title_basics_copy[df_title_basics_copy['tconst'] == 'tt0848228' ])
# Out:
#            tconst titleType  primaryTitle originalTitle isAdult  startYear  \
# 821056  tt0848228     movie  The Avengers  The Avengers       0       2012
#
#        endYear runtimeMinutes         genres
# 821056      \N            143  Action,Sci-Fi

# %%
print(df_tmdb[df_tmdb['imdb_id'] == 'tt0848228' ])
# Out:
#         adult                     backdrop_path     budget  \
# 165654  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  220000000
#
#                                             genres  \
# 165654  ['Science Fiction', 'Action', 'Adventure']
#
#                                           homepage     id    imdb_id  \
# 165654  https://www.marvel.com/movies/the-avengers  24428  tt0848228
#
#        original_language original_title  \
# 165654                en   The Avengers
#
#                                                  overview  ...  runtime  \
# 165654  When an unexpected enemy emerges and threatens...  ...      143
#
#           spoken_languages    status                  tagline         title  \
# 165654  ['en', 'hi', 'ru']  Released  Some assembly required.  The Avengers
#
#         video vote_average vote_count production_companies_name  \
# 165654  False        7.707      28541        ['Marvel Studios']
#
#        production_companies_country
# 165654                          NaN
#
# [1 rows x 25 columns]

# %%
# Jointure entre df_title_basics_copy et df_tmdb, clé communune : tconst et imdb_id
df_merged = pd.merge(df_title_basics_copy, df_tmdb, left_on='tconst', right_on='imdb_id', how='left')

# On enlève les colonnes inutiles
df_merged = df_merged.drop(columns=['isAdult', 'originalTitle', 'endYear', 'adult', 'budget', 'homepage', 'imdb_id', 'original_title', 'titleType', 'runtime'])

# On transforme les colonnes 'runtimeMinutes', 'id', 'popularity', 'runtime', 'revenue', 'vote_average', 'vote_count' en numérique
df_merged['runtimeMinutes'] = pd.to_numeric(df_merged['runtimeMinutes'], errors='coerce', downcast='signed').astype('Int64')  
df_merged['id'] = pd.to_numeric(df_merged['id'], errors='coerce', downcast='integer').astype('Int64')  
df_merged['popularity'] = pd.to_numeric(df_merged['popularity'], errors='coerce', downcast='signed')
df_merged['revenue'] = pd.to_numeric(df_merged['revenue'], errors='coerce', downcast='signed')
df_merged['vote_average'] = pd.to_numeric(df_merged['vote_average'], errors='coerce', downcast='signed')
df_merged['vote_count'] = pd.to_numeric(df_merged['vote_count'], errors='coerce', downcast='signed').astype('Int64')

# On transforme la colonne 'startYear' en datetime
df_title_basics_copy['startYear'] = pd.to_numeric(df_title_basics_copy['startYear'], errors='coerce',downcast ='signed').astype('Int64')
df_merged['startYear'] = pd.to_datetime(df_merged['startYear'], format='%Y', errors='coerce').dt.to_period('Y')

# On transforme la colonne 'release_date' en datetime
df_merged['release_date'] = pd.to_datetime(df_merged['release_date'], format='%Y-%m-%d', errors='coerce').dt.date

# On filtre la colonne 'production_country' pour ne garder que les pays de production souhaités : USA,FR,GB
df_filtered = df_merged[df_merged['production_countries'].str.contains('USA|GB|FR|US', na=False)]

# On réorganise les colonnes : 'tconst', 'primaryTitle', 'title', 'startYear', 'release_date', 'genre_x', 'genre_y', 'production_countries', 'runtimeMinutes', 'vote_average', 'vote_count', 'popularity', 'revenue', 'tagline', 'overview', 'id'
df_filtered = df_filtered[['tconst', 'primaryTitle', 'title', 'startYear', 'release_date', 'genres_x', 'genres_y', 'production_countries', 'runtimeMinutes', 'vote_average', 'vote_count', 'popularity', 'revenue', 'tagline', 'overview', 'id']]

# Renomme la colonne 'genres_x' en 'genres_df_title_basics' et genres_y en 'genres_df_tmdb'
df_filtered = df_filtered.rename(columns={'genres_x': 'genres_df_title_basics', 'genres_y': 'genres_df_tmdb'})


df_filtered
# Out:
#            tconst                          primaryTitle  \
# 3       tt0000591                      The Prodigal Son
# 34      tt0001101            Abraham Lincoln's Clemency
# 61      tt0001422                     Trail to the West
# 89      tt0001790  Les Misérables, Part 1: Jean Valjean
# 105     tt0002031                        As You Like It
# ...           ...                                   ...
# 566100  tt9907782                            The Cursed
# 566102  tt9908390                               Le lion
# 566106  tt9908636                Das Spiel der Hoffnung
# 566226  tt9916190                             Safeguard
# 566228  tt9916362                                 Coven
#
#                                         title startYear release_date  \
# 3                            The Prodigal Son      1907   1907-06-19
# 34                 Abraham Lincoln's Clemency      1910   1910-01-01
# 61                          Trail to the West      1910   1910-01-01
# 89      Les Misérables - Part 1: Jean Valjean      1913   1913-01-01
# 105                            As You Like It      1912   1912-10-06
# ...                                       ...       ...          ...
# 566100                             The Cursed      2021   2021-07-28
# 566102                               The Lion      2020   2020-01-29
# 566106                 Das Spiel der Hoffnung      2017   2017-05-25
# 566226                              Safeguard      2020   2020-09-07
# 566228                                  Coven      2020   2020-10-02
#
#            genres_df_title_basics                    genres_df_tmdb  \
# 3                           Drama                         ['Drama']
# 34                        Unknown                                []
# 61                        Unknown                       ['Western']
# 89                          Drama                       ['History']
# 105                       Unknown                        ['Comedy']
# ...                           ...                               ...
# 566100     Fantasy,Horror,Mystery  ['Horror', 'Fantasy', 'Mystery']
# 566102                     Comedy                        ['Comedy']
# 566106                    Fantasy                       ['Fantasy']
# 566226  Action,Adventure,Thriller   ['Action', 'Thriller', 'Crime']
# 566228              Drama,History              ['Drama', 'History']
#
#        production_countries  runtimeMinutes  vote_average  vote_count  \
# 3                    ['FR']              90         0.000           0
# 34                   ['US']            <NA>         0.000           0
# 61                   ['US']            <NA>         0.000           0
# 89                   ['FR']              60         1.000           1
# 105                  ['US']            <NA>         1.000           1
# ...                     ...             ...           ...         ...
# 566100               ['US']             111         6.900         169
# 566102               ['FR']              95         5.328         172
# 566106               ['GB']             100         0.000           0
# 566226               ['GB']              95         6.500           2
# 566228   ['AR', 'ES', 'FR']              92         6.708         257
#
#         popularity    revenue                                  tagline  \
# 3            0.600        0.0                                      NaN
# 34           0.600        0.0                                      NaN
# 61           0.600        0.0                                      NaN
# 89           0.874        0.0                                      NaN
# 105          0.882        0.0                                      NaN
# ...            ...        ...                                      ...
# 566100      22.872  4588389.0                                      NaN
# 566102       7.731        0.0                                      NaN
# 566106       0.897        0.0                                      NaN
# 566226       6.124        0.0  Protecting your family comes at a cost.
# 566228       8.629        0.0                                      NaN
#
#                                                  overview       id
# 3       The first feature-length motion picture produc...   396922
# 34      The plot revolves around US President Abraham ...  1086122
# 61                 Trail to the West is a silent Western.   929503
# 89      The story begins with Jean Valjean as a humble...   282219
# 105     After the overthrowing of Duke Senior by his t...   407055
# ...                                                   ...      ...
# 566100  In the late 19th century, a brutal land baron ...   630392
# 566102  A psychiatric hospital patient pretends to be ...   589970
# 566106  Follows the central character from infant inno...   688906
# 566226  When a Japanese restaurant is extorted by the ...   633490
# 566228  French Basque Country, year 1609. The men of a...   655187
#
# [65245 rows x 16 columns]

# %%
# Création d'un df pour les titres de films en francais et suppression des colonnes inutiles
df_title_akas_clean = df_title_akas.copy()
df_title_akas_clean = df_title_akas_clean.drop(columns=['ordering', 'language', 'types', 'attributes', 'isOriginalTitle'])

# Affiche les titres de la région FR
df_title_akas_clean = df_title_akas_clean[df_title_akas_clean['region'] == 'FR']

# Changement de la colonne 'title' en 'frenchTitle'
df_title_akas_clean = df_title_akas_clean.rename(columns={'title': 'frenchTitle'})

df_title_akas_clean.head(3)
# Out:
#       titleId             frenchTitle region
# 12  tt0000002  Le clown et ses chiens     FR
# 21  tt0000003          Pauvre Pierrot     FR
# 30  tt0000004             Un bon bock     FR

# %%
# Jointure entre df_filtered et df_title_akas_clean, clé communune : tconst et titleId
df_filtered_french_title = pd.merge(df_filtered, df_title_akas_clean, left_on='tconst', right_on='titleId', how='left')

#  Suppression des colonnes titleId, region
df_filtered_french_title = df_filtered_french_title.drop(columns=['titleId', 'region'], axis=1)

# Si frenchTitle est NaN, on remplace par primaryTitle
df_filtered_french_title['frenchTitle'] = df_filtered_french_title['frenchTitle'].fillna(df_filtered_french_title['primaryTitle'])


# Enleve les '[]' et les ' dans genres_df_tmdb
df_filtered_french_title['genres_df_tmdb'] = df_filtered_french_title['genres_df_tmdb'].apply(lambda x: str(x).replace('[','').replace(']','').replace('\'', '').replace(' ',''))

# Enleve les '[]' et les ' dans production_countries
df_filtered_french_title['production_countries'] = df_filtered_french_title['production_countries'].apply(lambda x: str(x).replace('[','').replace(']','').replace('\'', '').replace(' ',''))

# Concatene les colonnes 'genres_df_title_basics' et 'genres_df_tmdb' en une seule colonne 'genres' et supprime les termes en doublon de la colonne 'genres'
df_filtered_french_title['genres'] = df_filtered_french_title.apply(lambda x: ', '.join(set(str(x['genres_df_title_basics']).split(',') + str(x['genres_df_tmdb']).split(','))), axis=1)    

# Supprime les colonnes 'genres_df_title_basics' et 'genres_df_tmdb'
df_filtered_french_title = df_filtered_french_title.drop(columns=['genres_df_title_basics', 'genres_df_tmdb'], axis=1)

# Range les colonnes
df_filtered_french_title = df_filtered_french_title[['tconst', 'primaryTitle',  'title', 'frenchTitle','startYear', 'genres', 'production_countries', 'runtimeMinutes', 'vote_average', 'vote_count', 'popularity', 'revenue', 'tagline', 'overview', 'id']]

df_filtered_french_title.head(3)
# Out:
#       tconst                primaryTitle                       title  \
# 0  tt0000591            The Prodigal Son            The Prodigal Son
# 1  tt0001101  Abraham Lincoln's Clemency  Abraham Lincoln's Clemency
# 2  tt0001422           Trail to the West           Trail to the West
#
#                      frenchTitle startYear            genres  \
# 0              L'enfant prodigue      1907             Drama
# 1  La Clémence d'Abraham Lincoln      1910         , Unknown
# 2              Trail to the West      1910  Western, Unknown
#
#   production_countries  runtimeMinutes  vote_average  vote_count  popularity  \
# 0                   FR              90           0.0           0         0.6
# 1                   US            <NA>           0.0           0         0.6
# 2                   US            <NA>           0.0           0         0.6
#
#    revenue tagline                                           overview       id
# 0      0.0     NaN  The first feature-length motion picture produc...   396922
# 1      0.0     NaN  The plot revolves around US President Abraham ...  1086122
# 2      0.0     NaN             Trail to the West is a silent Western.   929503

# %%
df_filtered_french_title[df_filtered_french_title['tconst'] == 'tt0848228']
# Out:
#           tconst  primaryTitle         title frenchTitle startYear  \
# 43943  tt0848228  The Avengers  The Avengers    Avengers      2012
#
#                                           genres production_countries  \
# 43943  Sci-Fi, ScienceFiction, Action, Adventure                   US
#
#        runtimeMinutes  vote_average  vote_count  popularity       revenue  \
# 43943             143         7.707       28541     144.021  1.518816e+09
#
#                        tagline  \
# 43943  Some assembly required.
#
#                                                 overview     id
# 43943  When an unexpected enemy emerges and threatens...  24428

# %%
# Jointure entre df_filtered_french_title et df_title_ratings, clé commune : tconst
# On garde les colonnes 'tconst', 'averageRating', 'numVotes' et on supprime les colonnes 'vote_average', 'vote_count' et 'popularity' de df_filtered_french_title qui viennent de df_tmdb
df_filtered_ratings = pd.merge(df_filtered_french_title, df_title_ratings, left_on='tconst', right_on='tconst', how='left')

df_filtered_ratings = df_filtered_ratings.drop(columns=['vote_average', 'vote_count', 'popularity'], axis=1)
df_filtered_ratings['numVotes'] = df_filtered_ratings['numVotes'].astype('Int64')

# On enlève les films sans note
df_filtered_ratings = df_filtered_ratings[df_filtered_ratings['averageRating'].notna()]

# On enlève les films sortis avant 1990 dont la note est inférieure à 6 et le nombre de votes supérieurs a 1000, tout en  gardant les films sortis après 1990

df_filtered_ratings = df_filtered_ratings[~((df_filtered_ratings['startYear'].dt.year < 1990) & (df_filtered_ratings['averageRating'] < 6))]
df_filtered_ratings = df_filtered_ratings[~((df_filtered_ratings['startYear'].dt.year < 1990) & (df_filtered_ratings['numVotes'] < 1000))]

df_filtered_ratings.head(3)
# Out:
#        tconst                                       primaryTitle  \
# 22  tt0003643  The Avenging Conscience: or 'Thou Shalt Not Kill'
# 30  tt0003772                                         Cinderella
# 47  tt0004181                                 Judith of Bethulia
#
#                       title               frenchTitle startYear  \
# 22  The Avenging Conscience  La conscience vengeresse      1914
# 30               Cinderella                Cinderella      1914
# 47       Judith of Bethulia        Judith de Béthulie      1914
#
#                   genres production_countries  runtimeMinutes  revenue  \
# 22  Drama, Horror, Crime                   US              78      0.0
# 30        Drama, Fantasy                   US              52      0.0
# 47   Drama, History, War                   US              61      0.0
#
#                                          tagline  \
# 22  The criminal haunted by tortures of the mind
# 30                                           NaN
# 47                                           NaN
#
#                                              overview     id  averageRating  \
# 22  Thwarted by his despotic uncle from continuing...  28196            6.4
# 30  Based on Charles Perrault's fairy tale: Cinder...  92349            6.0
# 47  Griffith adapts the story of the Apocryphal Bo...  98078            6.2
#
#     numVotes
# 22      1531
# 30      1116
# 47      1501

# %%
df_filtered_ratings[df_filtered_ratings['tconst'] == 'tt0848228']
# Out:
#           tconst  primaryTitle         title frenchTitle startYear  \
# 43943  tt0848228  The Avengers  The Avengers    Avengers      2012
#
#                                           genres production_countries  \
# 43943  Sci-Fi, ScienceFiction, Action, Adventure                   US
#
#        runtimeMinutes       revenue                  tagline  \
# 43943             143  1.518816e+09  Some assembly required.
#
#                                                 overview     id  \
# 43943  When an unexpected enemy emerges and threatens...  24428
#
#        averageRating  numVotes
# 43943            8.0   1510211

# %%
# Suppression des doublons de la colonne 'tconst'
df_filtered_ratings_test = df_filtered_ratings.drop_duplicates(subset=['tconst'])
df_filtered_ratings_test.head(3)
# Out:
#        tconst                                       primaryTitle  \
# 22  tt0003643  The Avenging Conscience: or 'Thou Shalt Not Kill'
# 30  tt0003772                                         Cinderella
# 47  tt0004181                                 Judith of Bethulia
#
#                       title               frenchTitle startYear  \
# 22  The Avenging Conscience  La conscience vengeresse      1914
# 30               Cinderella                Cinderella      1914
# 47       Judith of Bethulia        Judith de Béthulie      1914
#
#                   genres production_countries  runtimeMinutes  revenue  \
# 22  Drama, Horror, Crime                   US              78      0.0
# 30        Drama, Fantasy                   US              52      0.0
# 47   Drama, History, War                   US              61      0.0
#
#                                          tagline  \
# 22  The criminal haunted by tortures of the mind
# 30                                           NaN
# 47                                           NaN
#
#                                              overview     id  averageRating  \
# 22  Thwarted by his despotic uncle from continuing...  28196            6.4
# 30  Based on Charles Perrault's fairy tale: Cinder...  92349            6.0
# 47  Griffith adapts the story of the Apocryphal Bo...  98078            6.2
#
#     numVotes
# 22      1531
# 30      1116
# 47      1501

# %%
df_filtered_ratings_test[df_filtered_ratings_test['tconst'] == 'tt0848228']
# Out:
#           tconst  primaryTitle         title frenchTitle startYear  \
# 43943  tt0848228  The Avengers  The Avengers    Avengers      2012
#
#                                           genres production_countries  \
# 43943  Sci-Fi, ScienceFiction, Action, Adventure                   US
#
#        runtimeMinutes       revenue                  tagline  \
# 43943             143  1.518816e+09  Some assembly required.
#
#                                                 overview     id  \
# 43943  When an unexpected enemy emerges and threatens...  24428
#
#        averageRating  numVotes
# 43943            8.0   1510211

# %%
df_cast = df_title_principals.copy()

df_cast = df_cast.merge(df_name_basics[['nconst', 'primaryName']], on='nconst', how='left')

df_cast = df_cast.sort_values(by=['tconst', 'ordering'])

df_cast[df_cast['tconst'] == 'tt0848228']
# Out:
#             tconst  ordering     nconst             category  \
# 9745119  tt0848228         1  nm0000375                actor
# 9745120  tt0848228         2  nm0000375                actor
# 9745121  tt0848228         3  nm0262635                actor
# 9745122  tt0848228         4  nm0262635                actor
# 9745123  tt0848228         5  nm0424060              actress
# 9745124  tt0848228         6  nm0424060              actress
# 9745125  tt0848228         7  nm0719637                actor
# 9745126  tt0848228         8  nm0719637                actor
# 9745127  tt0848228         9  nm0749263                actor
# 9745128  tt0848228        10  nm0749263                actor
# 9745129  tt0848228        11  nm1165110                actor
# 9745130  tt0848228        12  nm1089991                actor
# 9745131  tt0848228        13  nm0163988                actor
# 9745132  tt0848228        14  nm1130627              actress
# 9745133  tt0848228        15  nm0001745                actor
# 9745134  tt0848228        16  nm0923736             director
# 9745135  tt0848228        17  nm0923736               writer
# 9745136  tt0848228        18  nm0672015               writer
# 9745137  tt0848228        19  nm0270559             producer
# 9745138  tt0848228        20  nm0006293             composer
# 9745139  tt0848228        21  nm0568974      cinematographer
# 9745140  tt0848228        22  nm0285701               editor
# 9745141  tt0848228        23  nm0489809               editor
# 9745142  tt0848228        24  nm0278168     casting_director
# 9745143  tt0848228        25  nm0384900     casting_director
# 9745144  tt0848228        26  nm0157913  production_designer
#
#                              job              characters         primaryName
# 9745119                       \N          ["Tony Stark"]   Robert Downey Jr.
# 9745120                       \N            ["Iron Man"]   Robert Downey Jr.
# 9745121                       \N        ["Steve Rogers"]         Chris Evans
# 9745122                       \N     ["Captain America"]         Chris Evans
# 9745123                       \N    ["Natasha Romanoff"]  Scarlett Johansson
# 9745124                       \N         ["Black Widow"]  Scarlett Johansson
# 9745125                       \N        ["Clint Barton"]       Jeremy Renner
# 9745126                       \N             ["Hawkeye"]       Jeremy Renner
# 9745127                       \N        ["Bruce Banner"]        Mark Ruffalo
# 9745128                       \N            ["The Hulk"]        Mark Ruffalo
# 9745129                       \N                ["Thor"]     Chris Hemsworth
# 9745130                       \N                ["Loki"]      Tom Hiddleston
# 9745131                       \N  ["Agent Phil Coulson"]         Clark Gregg
# 9745132                       \N    ["Agent Maria Hill"]      Cobie Smulders
# 9745133                       \N              ["Selvig"]   Stellan Skarsgård
# 9745134                       \N                      \N         Joss Whedon
# 9745135               screenplay                      \N         Joss Whedon
# 9745136                    story                      \N            Zak Penn
# 9745137                 producer                      \N         Kevin Feige
# 9745138                       \N                      \N      Alan Silvestri
# 9745139  director of photography                      \N     Seamus McGarvey
# 9745140                       \N                      \N        Jeffrey Ford
# 9745141                       \N                      \N         Lisa Lassek
# 9745142         casting_director                      \N          Sarah Finn
# 9745143                       \N                      \N        Randi Hiller
# 9745144                       \N                      \N      James Chinlund

# %%
# On enleve les acteurs en doublons pour un tconst
df_cast = df_cast.drop_duplicates(subset=['tconst', 'nconst'])

df_cast[df_cast['tconst'] == 'tt0848228']
# Out:
#             tconst  ordering     nconst             category  \
# 9745119  tt0848228         1  nm0000375                actor
# 9745121  tt0848228         3  nm0262635                actor
# 9745123  tt0848228         5  nm0424060              actress
# 9745125  tt0848228         7  nm0719637                actor
# 9745127  tt0848228         9  nm0749263                actor
# 9745129  tt0848228        11  nm1165110                actor
# 9745130  tt0848228        12  nm1089991                actor
# 9745131  tt0848228        13  nm0163988                actor
# 9745132  tt0848228        14  nm1130627              actress
# 9745133  tt0848228        15  nm0001745                actor
# 9745134  tt0848228        16  nm0923736             director
# 9745136  tt0848228        18  nm0672015               writer
# 9745137  tt0848228        19  nm0270559             producer
# 9745138  tt0848228        20  nm0006293             composer
# 9745139  tt0848228        21  nm0568974      cinematographer
# 9745140  tt0848228        22  nm0285701               editor
# 9745141  tt0848228        23  nm0489809               editor
# 9745142  tt0848228        24  nm0278168     casting_director
# 9745143  tt0848228        25  nm0384900     casting_director
# 9745144  tt0848228        26  nm0157913  production_designer
#
#                              job              characters         primaryName
# 9745119                       \N          ["Tony Stark"]   Robert Downey Jr.
# 9745121                       \N        ["Steve Rogers"]         Chris Evans
# 9745123                       \N    ["Natasha Romanoff"]  Scarlett Johansson
# 9745125                       \N        ["Clint Barton"]       Jeremy Renner
# 9745127                       \N        ["Bruce Banner"]        Mark Ruffalo
# 9745129                       \N                ["Thor"]     Chris Hemsworth
# 9745130                       \N                ["Loki"]      Tom Hiddleston
# 9745131                       \N  ["Agent Phil Coulson"]         Clark Gregg
# 9745132                       \N    ["Agent Maria Hill"]      Cobie Smulders
# 9745133                       \N              ["Selvig"]   Stellan Skarsgård
# 9745134                       \N                      \N         Joss Whedon
# 9745136                    story                      \N            Zak Penn
# 9745137                 producer                      \N         Kevin Feige
# 9745138                       \N                      \N      Alan Silvestri
# 9745139  director of photography                      \N     Seamus McGarvey
# 9745140                       \N                      \N        Jeffrey Ford
# 9745141                       \N                      \N         Lisa Lassek
# 9745142         casting_director                      \N          Sarah Finn
# 9745143                       \N                      \N        Randi Hiller
# 9745144                       \N                      \N      James Chinlund

# %%
# On garde uniquement les 3 premiers acteurs par tconst
df_cast = df_cast.groupby('tconst').head(3)

# On garde les colonnes 'tconst', 'primaryName' 
df_cast = df_cast[['tconst', 'primaryName']]

df_cast[df_cast['tconst'] == 'tt0848228']
# Out:
#             tconst         primaryName
# 9745119  tt0848228   Robert Downey Jr.
# 9745121  tt0848228         Chris Evans
# 9745123  tt0848228  Scarlett Johansson

# %%
# On fait une colonne pour chaque acteur : Actor1, Actor2, Actor3
df_cast['actor_num'] = df_cast.groupby('tconst').cumcount() + 1
df_cast_pivot = df_cast.pivot(index='tconst', columns='actor_num', values='primaryName')
df_cast_pivot.columns = [f'actor{i}' for i in df_cast_pivot.columns]

df_cast_pivot = df_cast_pivot.reset_index()

df_cast_pivot[df_cast_pivot['tconst'] == 'tt0848228']
# Out:
#            tconst             actor1       actor2              actor3
# 809175  tt0848228  Robert Downey Jr.  Chris Evans  Scarlett Johansson

# %%
# On concatene df_filtered_ratings_test et df_cast_pivot sur la colonne tconst
df_actors = pd.merge(df_filtered_ratings_test, df_cast_pivot, on='tconst', how='left')

# %%
# Créer un filtre pour la colonne runtimeMinutes qui n'affiche que les films de plus de 60 minutes et de moins de 250 minutes
df_actors_filtered = df_actors[(df_actors['runtimeMinutes'] > 60) & (df_actors['runtimeMinutes'] < 250)]

df_actors_filtered.head(3)
# Out:
#       tconst                                       primaryTitle  \
# 0  tt0003643  The Avenging Conscience: or 'Thou Shalt Not Kill'
# 2  tt0004181                                 Judith of Bethulia
# 3  tt0004465                              The Perils of Pauline
#
#                      title               frenchTitle startYear  \
# 0  The Avenging Conscience  La conscience vengeresse      1914
# 2       Judith of Bethulia        Judith de Béthulie      1914
# 3    The Perils of Pauline     Les exploits d'Elaine      1914
#
#                      genres production_countries  runtimeMinutes  revenue  \
# 0      Drama, Horror, Crime                   US              78      0.0
# 2       Drama, History, War                   US              61      0.0
# 3  Drama, Adventure, Action                   US             199      0.0
#
#                                         tagline  \
# 0  The criminal haunted by tortures of the mind
# 2                                           NaN
# 3                                           NaN
#
#                                             overview     id  averageRating  \
# 0  Thwarted by his despotic uncle from continuing...  28196            6.4
# 2  Griffith adapts the story of the Apocryphal Bo...  98078            6.2
# 3  The Perils of Pauline is a motion picture seri...  36821            6.3
#
#    numVotes             actor1               actor2         actor3
# 0      1531  Henry B. Walthall  Spottiswoode Aitken  Blanche Sweet
# 2      1501      Blanche Sweet    Henry B. Walthall      Mae Marsh
# 3      1107        Pearl White         Crane Wilbur    Paul Panzer

# %%
df_actors_filtered[df_actors_filtered['tconst'] == 'tt0848228']
# Out:
#           tconst  primaryTitle         title frenchTitle startYear  \
# 18514  tt0848228  The Avengers  The Avengers    Avengers      2012
#
#                                           genres production_countries  \
# 18514  Sci-Fi, ScienceFiction, Action, Adventure                   US
#
#        runtimeMinutes       revenue                  tagline  \
# 18514             143  1.518816e+09  Some assembly required.
#
#                                                 overview     id  \
# 18514  When an unexpected enemy emerges and threatens...  24428
#
#        averageRating  numVotes             actor1       actor2  \
# 18514            8.0   1510211  Robert Downey Jr.  Chris Evans
#
#                    actor3
# 18514  Scarlett Johansson

# %%
df_actors_filtered.to_csv('../ressources/df_actor_col.csv', index=False)

# %%
# Merge des 3 df des acteurs et actrices/prodceurs etc...
df_merge_crew = pd.merge(df_title_crew, df_title_principals, left_on='tconst', right_on='tconst', how='left')
df_merge_crew_names = pd.merge(df_merge_crew, df_name_basics, left_on='nconst', right_on='nconst', how='left')

# On drop les colonnes inutiles -> ordering,  

df_merge_crew_names.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Merge des 3 df des acteurs et actrices/prodceurs etc...
# ----> 2 df_merge_crew = pd.merge(df_title_crew, df_title_principals, left_on='tconst', right_on='tconst', how='left')
#       3 df_merge_crew_names = pd.merge(df_merge_crew, df_name_basics, left_on='nconst', right_on='nconst', how='left')
#       5 # On drop les colonnes inutiles -> ordering,
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)    182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\reshape\merge.py:886, in _MergeOperation.get_result(self, copy)
#     883 if self.indicator:
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 886 join_index, left_indexer, right_indexer = self._get_join_info()
#     888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\reshape\merge.py:1151, in _MergeOperation._get_join_info(self)
#    1147     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1148         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1149     )
#    1150 else:
# -> 1151     (left_indexer, right_indexer) = self._get_join_indexers()
#    1153     if self.right_index:
#    1154         if len(self.left) > 0:
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\reshape\merge.py:1125, in _MergeOperation._get_join_indexers(self)
#    1123 # make mypy happy
#    1124 assert self.how != "asof"
# -> 1125 return get_join_indexers(
#    1126     self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1127 )
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\reshape\merge.py:1757, in get_join_indexers(left_keys, right_keys, sort, how)
#    1750 right = Index(rkey)
#    1752 if (
#    1753     left.is_monotonic_increasing
#    1754     and right.is_monotonic_increasing
#    1755     and (left.is_unique or right.is_unique)
#    1756 ):
# -> 1757     _, lidx, ridx = left.join(right, how=how, return_indexers=True, sort=sort)
#    1758 else:
#    1759     lidx, ridx = get_join_indexers_non_unique(
#    1760         left._values, right._values, sort, how
#    1761     )
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\indexes\base.py:279, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     269 @functools.wraps(meth)
#     270 def join(
#     271     self,
#    (...)    277     sort: bool = False,
#     278 ):
# --> 279     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     280     if not return_indexers:
#     281         return join_index
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\indexes\base.py:4652, in Index.join(self, other, how, level, return_indexers, sort)
#    4644 if (
#    4645     self.is_monotonic_increasing
#    4646     and other.is_monotonic_increasing
#    (...)   4649     and (self.is_unique or other.is_unique)
#    4650 ):
#    4651     try:
# -> 4652         return self._join_monotonic(other, how=how)
#    4653     except TypeError:
#    4654         # object dtype; non-comparable objects
#    4655         pass
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\indexes\base.py:5019, in Index._join_monotonic(self, other, how)
#    5017 else:
#    5018     if how == "left":
# -> 5019         join_array, lidx, ridx = self._left_indexer(other)
#    5020     elif how == "right":
#    5021         join_array, ridx, lidx = other._left_indexer(self)
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\indexes\base.py:394, in Index._left_indexer(self, other)
#     389 @final
#     390 def _left_indexer(
#     391     self, other: Self
#     392 ) -> tuple[ArrayLike, npt.NDArray[np.intp], npt.NDArray[np.intp]]:
#     393     # Caller is responsible for ensuring other.dtype == self.dtype
# --> 394     sv = self._get_join_target()
#     395     ov = other._get_join_target()
#     396     joined_ndarray, lidx, ridx = libjoin.left_join_indexer(sv, ov)
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\indexes\base.py:5204, in Index._get_join_target(self)
#    5201         return self._values.astype(object)
#    5202     return vals
# -> 5204 @final
#    5205 def _get_join_target(self) -> np.ndarray:
#    5206     """
#    5207     Get the ndarray or ExtensionArray that we can pass to the join
#    5208     functions.
#    5209     """
#    5210     if isinstance(self._values, BaseMaskedArray):
#    5211         # This is only used if our array is monotonic, so no NAs present
#
# KeyboardInterrupt:

# %%
df_merge_crew_names['category'].unique()

# On garde les categories les plus pertinentes pour suggerer un film a un néophyte -> actor, actress, director, producer, writer
df_merge_crew_names = df_merge_crew_names[df_merge_crew_names['category'].isin(['actor', 'actress', 'director', 'producer', 'writer'])]

# On suppime les colonnes inutiles -> ordering, directors, writers, nconst
df_merge_crew_names = df_merge_crew_names.drop(columns=['ordering', 'directors', 'writers', 'nconst'], axis=1)

# %%
df_merge_crew_names.head(3)
# Out:
#       tconst  category       job characters           primaryName birthYear  \
# 1  tt0000001  director        \N         \N  William K.L. Dickson      1860
# 2  tt0000001  producer  producer         \N  William K.L. Dickson      1860
# 4  tt0000002  director        \N         \N         Émile Reynaud      1844
#
#   deathYear                       primaryProfession  \
# 1      1935       cinematographer,director,producer
# 2      1935       cinematographer,director,producer
# 4      1918  director,animation_department,producer
#
#                                knownForTitles
# 1     tt1428455,tt1496763,tt0308254,tt0219560
# 2     tt1428455,tt1496763,tt0308254,tt0219560
# 4  tt0000003,tt32169968,tt16763740,tt16763674

# %%
# Transformer chaque catégorie en une colonne 
df_sample = df_merge_crew_names.sample(1000000, random_state=42)


#df_merge_crew_names_col_cat = df_sample.pivot_table(index='tconst', columns='category', values='primaryName', aggfunc=list, fill_value=[]).reset_index()
#df_merge_crew_names_col_cat

# %%
"""df_temp = df_filtered_ratings_test[['tconst', 'primaryTitle']]


# Merge entre df_temp et df_merge_crew_names
df_final = pd.merge(df_temp, df_merge_crew_names, left_on='tconst', right_on='tconst', how='left')

df_final"""
# Out:
# "df_temp = df_filtered_ratings_test[['tconst', 'primaryTitle']]\n\n\n# Merge entre df_temp et df_merge_crew_names\ndf_final = pd.merge(df_temp, df_merge_crew_names, left_on='tconst', right_on='tconst', how='left')\n\ndf_final"

# %%
#df_sample = df_merge_crew_names.sample(1000000, random_state=42)

# Étape 1 : grouper et concaténer les noms pour chaque tconst + category
df_grouped = (
    df_merge_crew_names
      .groupby(['tconst', 'category'])['primaryName']
      .apply(lambda names: 
             ', '.join(
               sorted(
                 {n for n in names if pd.notnull(n) and isinstance(n, str)}
               )
             )
      )
      .reset_index()
)

# Étape 2 : pivot pour avoir une colonne par catégorie
df_pivot = df_grouped.pivot(index='tconst', columns='category', values='primaryName') \
    .reset_index()

# Étape 3 : nettoyage
df_pivot.columns.name = None  # enlève le nom de l’index de colonne

# Résultat
df_pivot.head(3)
# Out:
#       tconst actor actress              director                     producer  \
# 0  tt0000001   NaN     NaN  William K.L. Dickson         William K.L. Dickson
# 1  tt0000002   NaN     NaN         Émile Reynaud                          NaN
# 2  tt0000003   NaN     NaN         Émile Reynaud  Julien Pappé, Émile Reynaud
#
#           writer
# 0            NaN
# 1            NaN
# 2  Émile Reynaud

# %%
# On enleve les colonnes category et primaryName
df_merge_crew_names_clean_cat = df_merge_crew_names.drop(columns=['category', 'primaryName'], axis=1)

# On concatene les colonnes 'birthYear' et 'deathYear' en une seule colonne 'birth_death_year'
df_merge_crew_names_clean_cat['deathYear'] = pd.to_numeric(df_merge_crew_names_clean_cat['deathYear'], errors='coerce')

df_merge_crew_names_clean_cat['birth_death_year'] = df_merge_crew_names_clean_cat.apply(lambda x: str(x['birthYear']) + '-' + str(x['deathYear']), axis=1)

# On supprime les colonnes birthYear et deathYear
df_merge_crew_names_clean_cat = df_merge_crew_names_clean_cat.drop(columns=['birthYear', 'deathYear', 'characters', 'primary'], axis=1)

# On merge df_merge_crew_names_clean_cat et df_pivot
df_merge_crew_final = pd.merge(df_merge_crew_names_clean_cat, df_pivot, left_on='tconst', right_on='tconst', how='left')

df_merge_crew_final.head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 10
#       7 df_merge_crew_names_clean_cat['birth_death_year'] = df_merge_crew_names_clean_cat.apply(lambda x: str(x['birthYear']) + '-' + str(x['deathYear']), axis=1)
#       9 # On supprime les colonnes birthYear et deathYear
# ---> 10 df_merge_crew_names_clean_cat = df_merge_crew_names_clean_cat.drop(columns=['birthYear', 'deathYear', 'characters', 'primary'], axis=1)
#      12 # On merge df_merge_crew_names_clean_cat et df_pivot
#      13 df_merge_crew_final = pd.merge(df_merge_crew_names_clean_cat, df_pivot, left_on='tconst', right_on='tconst', how='left')
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\User\Documents\Projet2\WildCodeSchool-Projet2\.venv\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['primary'] not found in axis"

# %%
df_tconst_crew.describe()
# Out:
#        runtimeMinutes       revenue             id  averageRating  \
# count         12665.0  1.266500e+04        12665.0   12665.000000
# mean       100.866403  7.959074e+06  270840.243111       6.068006
# std         18.336841  5.654873e+07  288564.234711       1.132547
# min              61.0  0.000000e+00           16.0       1.300000
# 25%              90.0  0.000000e+00        41271.0       5.500000
# 50%              98.0  0.000000e+00       128593.0       6.300000
# 75%             108.0  0.000000e+00       450050.0       6.800000
# max             240.0  2.923706e+09      1121899.0       9.700000
#
#            numVotes
# count       12665.0
# mean   17891.515989
# std    86636.947512
# min             6.0
# 25%           315.0
# 50%          1307.0
# 75%          5482.0
# max       3019825.0

# %%
df_tconst_crew.to_csv('df_final.csv', index=False, sep=';')

# %%
df_final = pd.read_csv('df_final.csv', sep=';', low_memory=False)
df_final
# Out:
#           tconst                           primaryTitle  \
# 0      tt0010307                              J'accuse!
# 1      tt0013933                     The Faithful Heart
# 2      tt0015014                            L'inhumaine
# 3      tt0017075  The Lodger: A Story of the London Fog
# 4      tt0017196                                   Nana
# ...          ...                                    ...
# 12660  tt9902160                                Herself
# 12661  tt9904802                            Enemy Lines
# 12662  tt9908390                                Le lion
# 12663  tt9916190                              Safeguard
# 12664  tt9916362                                  Coven
#
#                                        title               frenchTitle  \
# 0                                   J'accuse                  J'accuse
# 1                                Cœur fidèle              Coeur fidèle
# 2                                L'Inhumaine               L'inhumaine
# 3      The Lodger: A Story of the London Fog          Les cheveux d'or
# 4                                       Nana                      Nana
# ...                                      ...                       ...
# 12660                                Herself                   Herself
# 12661                            Enemy Lines               Enemy Lines
# 12662                               The Lion                   Le lion
# 12663                              Safeguard                 Safeguard
# 12664                                  Coven  Les sorcières d'Akelarre
#
#        startYear                                   genres  \
# 0           1919     Horror, War, Romance, Drama, History
# 1           1923                           Romance, Drama
# 2           1924  Romance, ScienceFiction, Drama, Mystery
# 3           1927          Thriller, Drama, Crime, Mystery
# 4           1926                           Romance, Drama
# ...          ...                                      ...
# 12660       2020                                    Drama
# 12661       2020                       Drama, Action, War
# 12662       2020                                   Comedy
# 12663       2020       Thriller, Adventure, Action, Crime
# 12664       2020                           Drama, History
#
#       production_countries  runtimeMinutes  revenue  \
# 0                       FR             166      0.0
# 1                       FR              87      0.0
# 2                       FR             135      0.0
# 3                       GB              92      0.0
# 4                       FR             150      0.0
# ...                    ...             ...      ...
# 12660                IE,GB              97      0.0
# 12661                   GB              92      0.0
# 12662                   FR              95      0.0
# 12663                   GB              95      0.0
# 12664             AR,ES,FR              92      0.0
#
#                                        tagline  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 12660                  Life under construction
# 12661                   Courage has no border.
# 12662                                      NaN
# 12663  Protecting your family comes at a cost.
# 12664                                      NaN
#
#                                                 overview      id  \
# 0      The story of two men, one married, the other t...   70804
# 1      The good guys win out in this sweet tale about...   67440
# 2      A famous singer Claire Lescot, who lives on th...   54539
# 3      London. A mysterious serial killer brutally mu...    2760
# 4      A government official, Count Muffat, falls und...   66812
# ...                                                  ...     ...
# 12660  Struggling to provide her daughters with a saf...  653708
# 12661  In the frozen, war torn landscape of occupied ...  679796
# 12662  A psychiatric hospital patient pretends to be ...  589970
# 12663  When a Japanese restaurant is extorted by the ...  633490
# 12664  French Basque Country, year 1609. The men of a...  655187
#
#        averageRating  numVotes  \
# 0                7.7      2240
# 1                7.4      1540
# 2                7.2      1134
# 3                7.3     14289
# 4                6.6      1011
# ...              ...       ...
# 12660            7.0      5099
# 12661            4.6      2041
# 12662            5.5      1497
# 12663            3.6       263
# 12664            6.4      6042
#
#                                                    actor  \
# 0      Blaise Cendrars, Maxime Desjardins, Paul Duc, ...
# 1         Claude Benedict, Edmond Van Daële, Léon Mathot
# 2      Fred Kellerman, Jaque Catelain, Las Bonambella...
# 3      Arthur Chesney, Ivor Novello, Malcolm Keen, Re...
# 4      Claude Autant-Lara, Jean Angelo, Karl Harbache...
# ...                                                  ...
# 12660    Art Kearns, Ian Lloyd Anderson, Shadaan Felfeli
# 12661  Corey Johnson, Daniel Jillings, Ed Westwick, G...
# 12662  Aksel Ustun, Benoît Pétré, Dany Boon, Mathieu ...
# 12663  Akie Kotabe, Andrei Nova, Lee Byford, Leo Ashi...
# 12664  Alex Brendemühl, Asier Oruesagasti, Daniel Fanego
#
#                                                  actress  \
# 0      Angèle Guys, Elizabeth Nizan, Mancini, Maryse ...
# 1      Gina Manès, Madame Maufroy, Madeleine Erickson...
# 2      Georgette Leblanc, Kiki of Montparnasse, Marce...
# 3      Daisy Campbell, Eve Gray, June Tripp, Marie Au...
# 4      Catherine Hessling, Jacqueline Forzane, Valesk...
# ...                                                  ...
# 12660  Anita Petry, Cathy Belton, Clare Dunne, Ericka...
# 12661                                    Maria Bondareva
# 12662          Anne Serra, Carole Brana, Sophie Verbeeck
# 12663                                        Yuriri Naka
# 12664  Amaia Aberasturi, Elena Uriz, Garazi Urkola, I...
#
#                      director  \
# 0                  Abel Gance
# 1                Jean Epstein
# 2            Marcel L'Herbier
# 3            Alfred Hitchcock
# 4                 Jean Renoir
# ...                       ...
# 12660          Phyllida Lloyd
# 12661            Anders Banke
# 12662  Ludovic Colbeau-Justin
# 12663         Fraser Precious
# 12664            Pablo Agüero
#
#                                                 producer  \
# 0                                          Charles Pathé
# 1                                                    NaN
# 2                                Marie-Laure de Noailles
# 3                                                    NaN
# 4                                            Jean Renoir
# ...                                                  ...
# 12660           Ed Guiney, Rory Gilmartin, Sharon Horgan
# 12661  Aleksandr Kushaev, Andy Thompson, Nadzeya Huse...
# 12662    Jean-Yves Robin, Marc Stanimirovic, Serge Hayat
# 12663                       Fraser Precious, Megan Young
# 12664             Fred Prémel, Iker Ganuza, Koldo Zuazua
#
#                                                   writer
# 0                                             Abel Gance
# 1                            Jean Epstein, Marie Epstein
# 2      Georgette Leblanc, Joris-Karl Huysmans, Marcel...
# 3                   Eliot Stannard, Marie Belloc Lowndes
# 4         Denise Leblond, Pierre Lestringuez, Émile Zola
# ...                                                  ...
# 12660                      Clare Dunne, Malcolm Campbell
# 12661                         Michael Wright, Tom George
# 12662              Alexandre Coquelle, Matthieu Le Naour
# 12663                                    Fraser Precious
# 12664                       Katell Guillou, Pablo Agüero
#
# [12665 rows x 19 columns]
